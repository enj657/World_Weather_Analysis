# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in set of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bima
# Processing Record 2 of Set 1 | takoradi
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | nouadhibou
# Processing Record 5 of Set 1 | codrington
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | valdivia
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | laguna
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | sawakin
# Processing Record 13 of Set 1 | siguiri
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | yanam
# Processing Record 16 of Set 1 | verkhniye kigi
# Processing Record 17 of Set 1 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | maniitsoq
# Processing Record 20 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | arkhangelos
# City not found. Skipping...
# Processing Record 29 of Set 1 | vardo
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | constitucion
# Processing Record 34 of Set 1 | novonukutskiy
# Processing Record 35 of Set 1 | carora
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | pisco
# Processing Record 38 of Set 1 | yulara
# Processing Record 39 of Set 1 | mackay
# Processing Record 40 of Set 1 | acapulco
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | tiarei
# Processing Record 43 of Set 1 | mingyue
# Processing Record 44 of Set 1 | nioro
# Processing Record 45 of Set 1 | mana
# Processing Record 46 of Set 1 | camapua
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | tsarychanka
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | ukiah
# Processing Record 2 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | bathsheba
# Processing Record 8 of Set 2 | halifax
# Processing Record 9 of Set 2 | pyu
# Processing Record 10 of Set 2 | amalapuram
# Processing Record 11 of Set 2 | pasni
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | necochea
# Processing Record 14 of Set 2 | sur
# Processing Record 15 of Set 2 | hamilton
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | tamandare
# Processing Record 18 of Set 2 | haifa
# Processing Record 19 of Set 2 | musoma
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | mount gambier
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | darnah
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | grindavik
# Processing Record 31 of Set 2 | davila
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | ossora
# Processing Record 34 of Set 2 | canton
# Processing Record 35 of Set 2 | nelson bay
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | vila franca do campo
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | sernovodskoye
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | okhotsk
# Processing Record 47 of Set 2 | hearst
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | nouakchott
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | troitsko-pechorsk
# Processing Record 3 of Set 3 | ulaangom
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | los llanos de aridane
# Processing Record 6 of Set 3 | gelemso
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | general cepeda
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | kuching
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | half moon bay
# Processing Record 16 of Set 3 | bandarbeyla
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | beyneu
# Processing Record 19 of Set 3 | san francisco menendez
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | thinadhoo
# Processing Record 23 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | asyut
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | komarov
# Processing Record 28 of Set 3 | boda
# Processing Record 29 of Set 3 | maceio
# Processing Record 30 of Set 3 | sarakhs
# Processing Record 31 of Set 3 | punta alta
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | labuhan
# Processing Record 34 of Set 3 | nishihara
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | nhlangano
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | zambezi
# Processing Record 40 of Set 3 | bereda
# Processing Record 41 of Set 3 | tari
# Processing Record 42 of Set 3 | vanimo
# Processing Record 43 of Set 3 | dossor
# Processing Record 44 of Set 3 | luoyang
# Processing Record 45 of Set 3 | angoche
# Processing Record 46 of Set 3 | mwene-ditu
# Processing Record 47 of Set 3 | amahai
# Processing Record 48 of Set 3 | tabou
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | pitimbu
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | mecca
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | saposoa
# Processing Record 5 of Set 4 | miyakonojo
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | takhli
# Processing Record 8 of Set 4 | korem
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | milledgeville
# Processing Record 12 of Set 4 | kitami
# Processing Record 13 of Set 4 | kabompo
# Processing Record 14 of Set 4 | ibra
# Processing Record 15 of Set 4 | shimoda
# Processing Record 16 of Set 4 | bartica
# Processing Record 17 of Set 4 | komarno
# Processing Record 18 of Set 4 | el dorado
# Processing Record 19 of Set 4 | amapa
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | conceicao das alagoas
# Processing Record 22 of Set 4 | tessalit
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | alice springs
# Processing Record 26 of Set 4 | hualmay
# Processing Record 27 of Set 4 | richards bay
# Processing Record 28 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 29 of Set 4 | jinka
# Processing Record 30 of Set 4 | astana
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | plouzane
# Processing Record 33 of Set 4 | svetlaya
# Processing Record 34 of Set 4 | kampong thum
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | ucluelet
# Processing Record 37 of Set 4 | talakan
# Processing Record 38 of Set 4 | cimarron hills
# Processing Record 39 of Set 4 | valparaiso
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | lichuan
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | havoysund
# Processing Record 45 of Set 4 | weston
# Processing Record 46 of Set 4 | mayor pablo lagerenza
# Processing Record 47 of Set 4 | sambava
# Processing Record 48 of Set 4 | kanungu
# Processing Record 49 of Set 4 | port macquarie
# Processing Record 50 of Set 4 | viesca
# Processing Record 1 of Set 5 | krasnoselkup
# Processing Record 2 of Set 5 | camacha
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | parnamirim
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 5 | ulladulla
# Processing Record 10 of Set 5 | ballina
# Processing Record 11 of Set 5 | acari
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | tshikapa
# Processing Record 14 of Set 5 | gizo
# Processing Record 15 of Set 5 | cafelandia
# Processing Record 16 of Set 5 | maryborough
# Processing Record 17 of Set 5 | krasnoye
# Processing Record 18 of Set 5 | gazojak
# Processing Record 19 of Set 5 | hambantota
# Processing Record 20 of Set 5 | ambilobe
# Processing Record 21 of Set 5 | abu samrah
# Processing Record 22 of Set 5 | katobu
# Processing Record 23 of Set 5 | lobito
# Processing Record 24 of Set 5 | woodward
# Processing Record 25 of Set 5 | lata
# Processing Record 26 of Set 5 | chuguyevka
# Processing Record 27 of Set 5 | sydney
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | porbandar
# Processing Record 30 of Set 5 | jumla
# Processing Record 31 of Set 5 | hovd
# Processing Record 32 of Set 5 | havre-saint-pierre
# Processing Record 33 of Set 5 | arlit
# Processing Record 34 of Set 5 | ocampo
# Processing Record 35 of Set 5 | obo
# Processing Record 36 of Set 5 | gemena
# Processing Record 37 of Set 5 | price
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | narsaq
# Processing Record 40 of Set 5 | maldonado
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | eureka
# Processing Record 43 of Set 5 | toora-khem
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | conakry
# Processing Record 47 of Set 5 | daru
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | annau
# Processing Record 50 of Set 5 | rizhao
# Processing Record 1 of Set 6 | saskylakh
# Processing Record 2 of Set 6 | beloha
# Processing Record 3 of Set 6 | abu dhabi
# Processing Record 4 of Set 6 | rodrigues alves
# Processing Record 5 of Set 6 | orocue
# Processing Record 6 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 6 | atar
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | andenes
# Processing Record 10 of Set 6 | sobolevo
# Processing Record 11 of Set 6 | maragogi
# Processing Record 12 of Set 6 | veraval
# Processing Record 13 of Set 6 | huejuquilla el alto
# Processing Record 14 of Set 6 | novikovo
# Processing Record 15 of Set 6 | cabo san lucas
# Processing Record 16 of Set 6 | sao felix do xingu
# Processing Record 17 of Set 6 | burica
# City not found. Skipping...
# Processing Record 18 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 6 | harper
# Processing Record 20 of Set 6 | srednekolymsk
# Processing Record 21 of Set 6 | dakar
# Processing Record 22 of Set 6 | egvekinot
# Processing Record 23 of Set 6 | porto belo
# Processing Record 24 of Set 6 | aksha
# Processing Record 25 of Set 6 | stephenville
# Processing Record 26 of Set 6 | balele
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | san quintin
# Processing Record 29 of Set 6 | tamasane
# Processing Record 30 of Set 6 | hasaki
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | zhaotong
# Processing Record 33 of Set 6 | sarangani
# Processing Record 34 of Set 6 | rio grande
# Processing Record 35 of Set 6 | weligama
# Processing Record 36 of Set 6 | tecoanapa
# Processing Record 37 of Set 6 | lorengau
# Processing Record 38 of Set 6 | cayenne
# Processing Record 39 of Set 6 | pacific grove
# Processing Record 40 of Set 6 | axim
# Processing Record 41 of Set 6 | ormara
# Processing Record 42 of Set 6 | borovoy
# Processing Record 43 of Set 6 | mahebourg
# Processing Record 44 of Set 6 | lavrentiya
# Processing Record 45 of Set 6 | klaksvik
# Processing Record 46 of Set 6 | zarnovica
# Processing Record 47 of Set 6 | chimoio
# Processing Record 48 of Set 6 | dawson creek
# Processing Record 49 of Set 6 | nuuk
# Processing Record 50 of Set 6 | dzerzhinsk
# Processing Record 1 of Set 7 | dosso
# Processing Record 2 of Set 7 | tuatapere
# Processing Record 3 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 7 | sao joao da barra
# Processing Record 5 of Set 7 | nyurba
# Processing Record 6 of Set 7 | hollister
# Processing Record 7 of Set 7 | bindura
# Processing Record 8 of Set 7 | san carlos de bariloche
# Processing Record 9 of Set 7 | tagusao
# Processing Record 10 of Set 7 | freeport
# Processing Record 11 of Set 7 | teguise
# Processing Record 12 of Set 7 | nachingwea
# Processing Record 13 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 7 | adrar
# Processing Record 17 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 18 of Set 7 | marquetalia
# Processing Record 19 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 7 | sfantu gheorghe
# Processing Record 21 of Set 7 | ouegoa
# Processing Record 22 of Set 7 | guarapari
# Processing Record 23 of Set 7 | yichang
# Processing Record 24 of Set 7 | jackson
# Processing Record 25 of Set 7 | boissevain
# Processing Record 26 of Set 7 | lasa
# Processing Record 27 of Set 7 | provideniya
# Processing Record 28 of Set 7 | camana
# Processing Record 29 of Set 7 | iracoubo
# Processing Record 30 of Set 7 | warrnambool
# Processing Record 31 of Set 7 | mayya
# Processing Record 32 of Set 7 | salta
# Processing Record 33 of Set 7 | carauari
# Processing Record 34 of Set 7 | tokur
# Processing Record 35 of Set 7 | samarai
# Processing Record 36 of Set 7 | novocheremshansk
# Processing Record 37 of Set 7 | luganville
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | feldkirchen an der donau
# Processing Record 40 of Set 7 | puerto baquerizo moreno
# Processing Record 41 of Set 7 | kabelvag
# Processing Record 42 of Set 7 | sinnamary
# Processing Record 43 of Set 7 | geraldton
# Processing Record 44 of Set 7 | tuktoyaktuk
# Processing Record 45 of Set 7 | sept-iles
# Processing Record 46 of Set 7 | tautira
# Processing Record 47 of Set 7 | boa vista
# Processing Record 48 of Set 7 | bagdarin
# Processing Record 49 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 7 | gorom-gorom
# Processing Record 1 of Set 8 | manggar
# Processing Record 2 of Set 8 | namibe
# Processing Record 3 of Set 8 | najran
# Processing Record 4 of Set 8 | hastings
# Processing Record 5 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 8 | mandla
# Processing Record 7 of Set 8 | san ciro de acosta
# Processing Record 8 of Set 8 | kofele
# Processing Record 9 of Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 10 of Set 8 | sokoto
# Processing Record 11 of Set 8 | yerbogachen
# Processing Record 12 of Set 8 | ahuimanu
# Processing Record 13 of Set 8 | jabinyanah
# Processing Record 14 of Set 8 | foam lake
# Processing Record 15 of Set 8 | apaseo el alto
# Processing Record 16 of Set 8 | barnstaple
# Processing Record 17 of Set 8 | lima
# Processing Record 18 of Set 8 | kieta
# Processing Record 19 of Set 8 | slave lake
# Processing Record 20 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 8 | mandalay
# Processing Record 22 of Set 8 | hudson bay
# Processing Record 23 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | bronnoysund
# Processing Record 26 of Set 8 | san cristobal
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | kwekwe
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | ustyuzhna
# Processing Record 31 of Set 8 | sagaing
# Processing Record 32 of Set 8 | wielun
# Processing Record 33 of Set 8 | kabinda
# Processing Record 34 of Set 8 | itapirapua
# Processing Record 35 of Set 8 | isakly
# Processing Record 36 of Set 8 | karpinsk
# Processing Record 37 of Set 8 | duiwelskloof
# Processing Record 38 of Set 8 | miri
# Processing Record 39 of Set 8 | mehamn
# Processing Record 40 of Set 8 | kaitangata
# Processing Record 41 of Set 8 | mangrol
# Processing Record 42 of Set 8 | kavieng
# Processing Record 43 of Set 8 | kushima
# Processing Record 44 of Set 8 | huarmey
# Processing Record 45 of Set 8 | mariental
# Processing Record 46 of Set 8 | aklavik
# Processing Record 47 of Set 8 | padre zamora
# Processing Record 48 of Set 8 | iranshahr
# Processing Record 49 of Set 8 | bilma
# Processing Record 50 of Set 8 | roald
# Processing Record 1 of Set 9 | pangnirtung
# Processing Record 2 of Set 9 | san andres
# Processing Record 3 of Set 9 | manokwari
# Processing Record 4 of Set 9 | arona
# Processing Record 5 of Set 9 | zhigansk
# Processing Record 6 of Set 9 | mnogovershinnyy
# Processing Record 7 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 9 | tubuala
# Processing Record 9 of Set 9 | ugoofaaru
# Processing Record 10 of Set 9 | leshukonskoye
# Processing Record 11 of Set 9 | nabire
# Processing Record 12 of Set 9 | lamont
# Processing Record 13 of Set 9 | yumen
# Processing Record 14 of Set 9 | krasnogorskoye
# Processing Record 15 of Set 9 | bentiu
# Processing Record 16 of Set 9 | saskatoon
# Processing Record 17 of Set 9 | the valley
# Processing Record 18 of Set 9 | wasco
# Processing Record 19 of Set 9 | ligayan
# Processing Record 20 of Set 9 | hobyo
# Processing Record 21 of Set 9 | elizabeth city
# Processing Record 22 of Set 9 | ganzhou
# Processing Record 23 of Set 9 | te anau
# Processing Record 24 of Set 9 | togur
# Processing Record 25 of Set 9 | ixtapa
# Processing Record 26 of Set 9 | port moresby
# Processing Record 27 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 9 | kikwit
# Processing Record 29 of Set 9 | maple creek
# Processing Record 30 of Set 9 | beaverlodge
# Processing Record 31 of Set 9 | novobirilyussy
# Processing Record 32 of Set 9 | port-gentil
# Processing Record 33 of Set 9 | coihaique
# Processing Record 34 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 9 | beidao
# Processing Record 36 of Set 9 | tocopilla
# Processing Record 37 of Set 9 | malangali
# Processing Record 38 of Set 9 | barstow
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | jinhua
# Processing Record 41 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 9 | hanzhong
# Processing Record 43 of Set 9 | gardabani
# Processing Record 44 of Set 9 | ankazoabo
# Processing Record 45 of Set 9 | ilam
# Processing Record 46 of Set 9 | mulege
# Processing Record 47 of Set 9 | antalaha
# Processing Record 48 of Set 9 | luena
# Processing Record 49 of Set 9 | asilah
# Processing Record 50 of Set 9 | cabra
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | kedrovyy
# Processing Record 3 of Set 10 | almaznyy
# Processing Record 4 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 10 | dumai
# Processing Record 6 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 8 of Set 10 | jinchang
# Processing Record 9 of Set 10 | marystown
# Processing Record 10 of Set 10 | nyimba
# Processing Record 11 of Set 10 | tiznit
# Processing Record 12 of Set 10 | saint-joseph
# Processing Record 13 of Set 10 | marsh harbour
# Processing Record 14 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 15 of Set 10 | teguldet
# Processing Record 16 of Set 10 | bilibino
# Processing Record 17 of Set 10 | goycay
# City not found. Skipping...
# Processing Record 18 of Set 10 | saint-denis
# Processing Record 19 of Set 10 | namie
# Processing Record 20 of Set 10 | marzuq
# Processing Record 21 of Set 10 | kempele
# Processing Record 22 of Set 10 | buala
# Processing Record 23 of Set 10 | carmo do paranaiba
# Processing Record 24 of Set 10 | porto novo
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | senftenberg
# Processing Record 27 of Set 10 | sao raimundo das mangabeiras
# Processing Record 28 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 10 | bam
# Processing Record 30 of Set 10 | mercedes
# Processing Record 31 of Set 10 | offa
# Processing Record 32 of Set 10 | isangel
# Processing Record 33 of Set 10 | gimli
# Processing Record 34 of Set 10 | tukrah
# Processing Record 35 of Set 10 | shelburne
# Processing Record 36 of Set 10 | umm kaddadah
# Processing Record 37 of Set 10 | naro moru
# Processing Record 38 of Set 10 | mocuba
# Processing Record 39 of Set 10 | sosnovo-ozerskoye
# Processing Record 40 of Set 10 | marawi
# Processing Record 41 of Set 10 | helong
# Processing Record 42 of Set 10 | taoudenni
# Processing Record 43 of Set 10 | ariquemes
# Processing Record 44 of Set 10 | arteche
# Processing Record 45 of Set 10 | tariba
# Processing Record 46 of Set 10 | martapura
# Processing Record 47 of Set 10 | purgstall
# Processing Record 48 of Set 10 | piacabucu
# Processing Record 49 of Set 10 | ilulissat
# Processing Record 50 of Set 10 | devils lake
# Processing Record 1 of Set 11 | stornoway
# Processing Record 2 of Set 11 | kailua
# Processing Record 3 of Set 11 | timra
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | chuy
# Processing Record 6 of Set 11 | paamiut
# Processing Record 7 of Set 11 | saint anthony
# Processing Record 8 of Set 11 | dwarka
# Processing Record 9 of Set 11 | bajil
# Processing Record 10 of Set 11 | channel-port aux basques
# Processing Record 11 of Set 11 | manavgat
# Processing Record 12 of Set 11 | magan
# Processing Record 13 of Set 11 | san luis
# Processing Record 14 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | rawson
# Processing Record 17 of Set 11 | hennef
# Processing Record 18 of Set 11 | eenhana
# Processing Record 19 of Set 11 | asuncion nochixtlan
# Processing Record 20 of Set 11 | yar-sale
# Processing Record 21 of Set 11 | aswan
# Processing Record 22 of Set 11 | fukue
# Processing Record 23 of Set 11 | kamenka
# Processing Record 24 of Set 11 | kinshasa
# Processing Record 25 of Set 11 | santa rosa
# Processing Record 26 of Set 11 | vestmanna
# Processing Record 27 of Set 11 | ayan
# Processing Record 28 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 29 of Set 11 | mindif
# Processing Record 30 of Set 11 | ilhabela
# Processing Record 31 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 32 of Set 11 | buluang
# Processing Record 33 of Set 11 | saint-jean-de-maurienne
# Processing Record 34 of Set 11 | chapais
# Processing Record 35 of Set 11 | saint-augustin
# Processing Record 36 of Set 11 | mayskiy
# Processing Record 37 of Set 11 | makakilo city
# Processing Record 38 of Set 11 | husavik
# Processing Record 39 of Set 11 | perene
# Processing Record 40 of Set 11 | ewa beach
# Processing Record 41 of Set 11 | sung noen
# Processing Record 42 of Set 11 | luanda
# Processing Record 43 of Set 11 | gazli
# Processing Record 44 of Set 11 | vienna
# Processing Record 45 of Set 11 | eirunepe
# Processing Record 46 of Set 11 | prieska
# Processing Record 47 of Set 11 | fatehabad
# Processing Record 48 of Set 11 | varena
# Processing Record 49 of Set 11 | raudeberg
# Processing Record 50 of Set 11 | boddam
# Processing Record 1 of Set 12 | aljezur
# Processing Record 2 of Set 12 | mastic beach
# Processing Record 3 of Set 12 | west wendover
# Processing Record 4 of Set 12 | hirara
# Processing Record 5 of Set 12 | carutapera
# Processing Record 6 of Set 12 | puerto escondido
# Processing Record 7 of Set 12 | margate
# Processing Record 8 of Set 12 | olinda
# Processing Record 9 of Set 12 | san pedro
# Processing Record 10 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 12 | christchurch
# Processing Record 12 of Set 12 | bo
# City not found. Skipping...
# Processing Record 13 of Set 12 | shushenskoye
# Processing Record 14 of Set 12 | sheregesh
# Processing Record 15 of Set 12 | taitung
# Processing Record 16 of Set 12 | almenara
# Processing Record 17 of Set 12 | saldanha
# Processing Record 18 of Set 12 | vestmannaeyjar
# Processing Record 19 of Set 12 | garachine
# Processing Record 20 of Set 12 | ahipara
# Processing Record 21 of Set 12 | sibsagar
# Processing Record 22 of Set 12 | puerto rico
# Processing Record 23 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 24 of Set 12 | chaihe
# Processing Record 25 of Set 12 | qaqortoq
# Processing Record 26 of Set 12 | xuddur
# Processing Record 27 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 28 of Set 12 | batman
# Processing Record 29 of Set 12 | novosheshminsk
# Processing Record 30 of Set 12 | chateau-thierry
# Processing Record 31 of Set 12 | katangli
# Processing Record 32 of Set 12 | verkhnevilyuysk
# Processing Record 33 of Set 12 | marathon
# Processing Record 34 of Set 12 | lakes entrance
# Processing Record 35 of Set 12 | chicama
# Processing Record 36 of Set 12 | aykhal
# Processing Record 37 of Set 12 | north bend
# Processing Record 38 of Set 12 | gombong
# Processing Record 39 of Set 12 | havelock
# Processing Record 40 of Set 12 | qingyuan
# Processing Record 41 of Set 12 | tilichiki
# Processing Record 42 of Set 12 | malampaka
# Processing Record 43 of Set 12 | huilong
# Processing Record 44 of Set 12 | cherskiy
# Processing Record 45 of Set 12 | moose factory
# Processing Record 46 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 12 | tommot
# Processing Record 48 of Set 12 | mandalgovi
# Processing Record 49 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 12 | rafraf
# Processing Record 1 of Set 13 | folkestone
# Processing Record 2 of Set 13 | broome
# Processing Record 3 of Set 13 | belyy yar
# Processing Record 4 of Set 13 | zhanaozen
# Processing Record 5 of Set 13 | gueugnon
# Processing Record 6 of Set 13 | bowen
# Processing Record 7 of Set 13 | ust-omchug
# Processing Record 8 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 9 of Set 13 | sosnovka
# Processing Record 10 of Set 13 | riwaka
# Processing Record 11 of Set 13 | amga
# Processing Record 12 of Set 13 | ostrovnoy
# Processing Record 13 of Set 13 | vao
# Processing Record 14 of Set 13 | padang
# Processing Record 15 of Set 13 | kerema
# Processing Record 16 of Set 13 | turayf
# Processing Record 17 of Set 13 | poso
# Processing Record 18 of Set 13 | savinka
# Processing Record 19 of Set 13 | prince rupert
# Processing Record 20 of Set 13 | ambanja
# Processing Record 21 of Set 13 | fairbanks
# Processing Record 22 of Set 13 | larap
# Processing Record 23 of Set 13 | killybegs
# Processing Record 24 of Set 13 | ternate
# Processing Record 25 of Set 13 | longyearbyen
# Processing Record 26 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 13 | suluq
# Processing Record 28 of Set 13 | khangarh
# Processing Record 29 of Set 13 | naryan-mar
# Processing Record 30 of Set 13 | meadow lake
# Processing Record 31 of Set 13 | otradnoye
# Processing Record 32 of Set 13 | mill valley
# Processing Record 33 of Set 13 | korla
# Processing Record 34 of Set 13 | kot diji
# Processing Record 35 of Set 13 | taltal
# Processing Record 36 of Set 13 | mahishadal
# Processing Record 37 of Set 13 | koslan
# Processing Record 38 of Set 13 | fergus falls
# Processing Record 39 of Set 13 | watsa
# Processing Record 40 of Set 13 | manaus
# Processing Record 41 of Set 13 | dukat
# Processing Record 42 of Set 13 | sabang
# Processing Record 43 of Set 13 | sorland
# Processing Record 44 of Set 13 | teresina
# Processing Record 45 of Set 13 | el reno
# Processing Record 46 of Set 13 | haines junction
# Processing Record 47 of Set 13 | matara
# Processing Record 48 of Set 13 | bonthe
# Processing Record 49 of Set 13 | dunedin
# Processing Record 50 of Set 13 | kaduna
# Processing Record 1 of Set 14 | cururupu
# Processing Record 2 of Set 14 | pirovskoye
# Processing Record 3 of Set 14 | kloulklubed
# Processing Record 4 of Set 14 | zemio
# Processing Record 5 of Set 14 | eydhafushi
# Processing Record 6 of Set 14 | meulaboh
# Processing Record 7 of Set 14 | verkhoyansk
# Processing Record 8 of Set 14 | mount isa
# Processing Record 9 of Set 14 | milkovo
# Processing Record 10 of Set 14 | kavaratti
# Processing Record 11 of Set 14 | guanica
# Processing Record 12 of Set 14 | heilbron
# Processing Record 13 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 14 | nome
# Processing Record 15 of Set 14 | flinders
# Processing Record 16 of Set 14 | sinazongwe
# Processing Record 17 of Set 14 | laurel
# Processing Record 18 of Set 14 | narasannapeta
# Processing Record 19 of Set 14 | yamandu
# Processing Record 20 of Set 14 | iglino
# Processing Record 21 of Set 14 | bunawan
# Processing Record 22 of Set 14 | victor harbor
# Processing Record 23 of Set 14 | ketchikan
# Processing Record 24 of Set 14 | odemis
# City not found. Skipping...
# Processing Record 25 of Set 14 | kawardha
# Processing Record 26 of Set 14 | salalah
# Processing Record 27 of Set 14 | sopelana
# Processing Record 28 of Set 14 | walvis bay
# Processing Record 29 of Set 14 | dali
# Processing Record 30 of Set 14 | kawalu
# Processing Record 31 of Set 14 | bandrele
# Processing Record 32 of Set 14 | sikonge
# Processing Record 33 of Set 14 | doka
# Processing Record 34 of Set 14 | la ronge
# Processing Record 35 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 14 | mbaiki
# Processing Record 37 of Set 14 | thaba-tseka
# Processing Record 38 of Set 14 | auchel
# Processing Record 39 of Set 14 | chernyshevskiy
# Processing Record 40 of Set 14 | salinopolis
# Processing Record 41 of Set 14 | ciudad bolivar
# Processing Record 42 of Set 14 | owings mills
# Processing Record 43 of Set 14 | bubaque
# Processing Record 44 of Set 14 | ginda
# Processing Record 45 of Set 14 | gushikawa
# Processing Record 46 of Set 14 | gilgit
# Processing Record 47 of Set 14 | kadirli
# Processing Record 48 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 14 | hay river
# Processing Record 50 of Set 14 | lincoln
# Processing Record 1 of Set 15 | mayo
# Processing Record 2 of Set 15 | shenzhen
# Processing Record 3 of Set 15 | erzin
# Processing Record 4 of Set 15 | jingdezhen
# Processing Record 5 of Set 15 | nador
# Processing Record 6 of Set 15 | owando
# Processing Record 7 of Set 15 | kasama
# Processing Record 8 of Set 15 | sainte-maxime
# Processing Record 9 of Set 15 | katsuura
# Processing Record 10 of Set 15 | zabol
# Processing Record 11 of Set 15 | grand gaube
# Processing Record 12 of Set 15 | hirado
# Processing Record 13 of Set 15 | cabedelo
# Processing Record 14 of Set 15 | ayr
# Processing Record 15 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 15 | las vigas
# Processing Record 17 of Set 15 | flin flon
# Processing Record 18 of Set 15 | orotukan
# Processing Record 19 of Set 15 | teeli
# Processing Record 20 of Set 15 | agua branca
# Processing Record 21 of Set 15 | maneadero
# Processing Record 22 of Set 15 | scottsbluff
# Processing Record 23 of Set 15 | peniche
# Processing Record 24 of Set 15 | erice
# Processing Record 25 of Set 15 | donaueschingen
# Processing Record 26 of Set 15 | horodnytsya
# Processing Record 27 of Set 15 | yurty
# Processing Record 28 of Set 15 | naze
# Processing Record 29 of Set 15 | concepcion del oro
# Processing Record 30 of Set 15 | teloes
# Processing Record 31 of Set 15 | cascais
# Processing Record 32 of Set 15 | luzhou
# Processing Record 33 of Set 15 | macae
# Processing Record 34 of Set 15 | jacareacanga
# Processing Record 35 of Set 15 | muros
# Processing Record 36 of Set 15 | lethem
# Processing Record 37 of Set 15 | pemba
# Processing Record 38 of Set 15 | imbituba
# Processing Record 39 of Set 15 | san borja
# Processing Record 40 of Set 15 | kisangani
# Processing Record 41 of Set 15 | acarau
# Processing Record 42 of Set 15 | sheridan
# Processing Record 43 of Set 15 | upata
# Processing Record 44 of Set 15 | chegdomyn
# Processing Record 45 of Set 15 | lafiagi
# Processing Record 46 of Set 15 | birao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Bima  -8.4667  118.7167     76.57        90          96        4.90
# 1    Takoradi   4.8845   -1.7554     80.74        77          57        9.78
# 2  Nouadhibou  20.9310  -17.0347     84.18        58           1       14.97
# 3  Codrington -38.2667  141.9667     45.86        80          20       10.13
# 4   Busselton -33.6500  115.3333     44.10        72          88       11.25
#
#   Country      Description
# 0      ID  overcast clouds
# 1      GH    broken clouds
# 2      MR             sand
# 3      AU       few clouds
# 4      AU  overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bima      ID  -8.4667  118.7167     76.57        90          96
# 1    Takoradi      GH   4.8845   -1.7554     80.74        77          57
# 2  Nouadhibou      MR  20.9310  -17.0347     84.18        58           1
# 3  Codrington      AU -38.2667  141.9667     45.86        80          20
# 4   Busselton      AU -33.6500  115.3333     44.10        72          88
#
#    Wind Speed      Description
# 0        4.90  overcast clouds
# 1        9.78    broken clouds
# 2       14.97             sand
# 3       10.13       few clouds
# 4       11.25  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
